# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras import backend as K

# %%
def euclidean_distance(vectors):
    x, y = vectors
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))

# %%
def euclidean_distance_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
model = load_model(
    "signature_siamese_model1.h5",
    custom_objects={
        "euclidean_distance": euclidean_distance,
        "euclidean_distance_output_shape": euclidean_distance_output_shape
    },
    compile=False
)

print("Model Loaded Successfully")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model = load_model(
#       2     "signature_siamese_model1.h5",
#       3     custom_objects={
#       4         "euclidean_distance": euclidean_distance,
#       5         "euclidean_distance_output_shape": euclidean_distance_output_shape
#       6     },
#       7     compile=False
#       8 )
#      10 print("Model Loaded Successfully")
#
# File c:\Users\aviru\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
#     200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#
# File c:\Users\aviru\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:132, in load_model_from_hdf5(filepath, custom_objects, compile)
#     129 model_config = json_utils.decode(model_config)
#     131 with saving_options.keras_option_scope(use_legacy_config=True):
# --> 132     model = saving_utils.model_from_config(
#     133         model_config, custom_objects=custom_objects
#     134     )
#     136     # set weights
#     137     load_weights_from_hdf5_group(f["model_weights"], model)
#
# File c:\Users\aviru\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:88, in model_from_config(config, custom_objects)
#      84 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      85 # Replace keras refs with keras
#      86 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 88 return serialization.deserialize_keras_object(
#      89     config,
#      90     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      91     custom_objects=custom_objects,
#      92     printable_module_name="layer",
#      93 )
#
# File c:\Users\aviru\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\legacy\saving\serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File c:\Users\aviru\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\models\model.py:660, in Model.from_config(cls, config, custom_objects)
#     655 if is_functional_config and revivable_as_functional:
#     656     # Revive Functional model
#     657     # (but not Functional subclasses with a custom __init__)
#     658     from keras.src.models.functional import functional_from_config
# --> 660     return functional_from_config(
#     661         cls, config, custom_objects=custom_objects
#     662     )
#     664 # Either the model has a custom __init__, or the config
#     665 # does not contain all the information necessary to
#     666 # revive a Functional model. This happens when the user creates
#    (...)    669 # In this case, we fall back to provide all config into the
#     670 # constructor of the class.
#     671 try:
#
# File c:\Users\aviru\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\models\functional.py:558, in functional_from_config(cls, config, custom_objects)
#     556 # First, we create all layers and enqueue nodes to be processed
#     557 for layer_data in functional_config["layers"]:
# --> 558     process_layer(layer_data)
#     560 # Then we process nodes in order of layer depth.
#     561 # Nodes that cannot yet be processed (if the inbound node
#     562 # does not yet exist) are re-enqueued, and the process
#     563 # is repeated until all nodes are processed.
#     564 while unprocessed_nodes:
#
# File c:\Users\aviru\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\models\functional.py:521, in functional_from_config.<locals>.process_layer(layer_data)
#     517 # Instantiate layer.
#     518 if "module" not in layer_data:
#     519     # Legacy format deserialization (no "module" key)
#     520     # used for H5 and SavedModel formats
# --> 521     layer = saving_utils.model_from_config(
#     522         layer_data, custom_objects=custom_objects
#     523     )
#     524 else:
#     525     layer = serialization_lib.deserialize_keras_object(
#     526         layer_data, custom_objects=custom_objects
#     527     )
#
# File c:\Users\aviru\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:88, in model_from_config(config, custom_objects)
#      84 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      85 # Replace keras refs with keras
#      86 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 88 return serialization.deserialize_keras_object(
#      89     config,
#      90     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      91     custom_objects=custom_objects,
#      92     printable_module_name="layer",
#      93 )
#
# File c:\Users\aviru\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\legacy\saving\serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File c:\Users\aviru\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\models\model.py:660, in Model.from_config(cls, config, custom_objects)
#     655 if is_functional_config and revivable_as_functional:
#     656     # Revive Functional model
#     657     # (but not Functional subclasses with a custom __init__)
#     658     from keras.src.models.functional import functional_from_config
# --> 660     return functional_from_config(
#     661         cls, config, custom_objects=custom_objects
#     662     )
#     664 # Either the model has a custom __init__, or the config
#     665 # does not contain all the information necessary to
#     666 # revive a Functional model. This happens when the user creates
#    (...)    669 # In this case, we fall back to provide all config into the
#     670 # constructor of the class.
#     671 try:
#
# File c:\Users\aviru\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\models\functional.py:577, in functional_from_config(cls, config, custom_objects)
#     575 node_data = node_data_list[node_index]
#     576 try:
# --> 577     process_node(layer, node_data)
#     579 # If the node does not have all inbound layers
#     580 # available, stop processing and continue later
#     581 except IndexError:
#
# File c:\Users\aviru\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\models\functional.py:507, in functional_from_config.<locals>.process_node(layer, node_data)
#     504 args, kwargs = deserialize_node(node_data, created_layers)
#     505 # Call layer on its inputs, thus creating the node
#     506 # and building the layer if needed.
# --> 507 layer(*args, **kwargs)
#
# File c:\Users\aviru\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\aviru\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\lambda_layer.py:95, in Lambda.compute_output_shape(self, input_shape)
#      93         return tree.map_structure(lambda x: x.shape, output_spec)
#      94     except:
# ---> 95         raise NotImplementedError(
#      96             "We could not automatically infer the shape of "
#      97             "the Lambda's output. Please specify the `output_shape` "
#      98             "argument for this Lambda layer."
#      99         )
#     101 if callable(self._output_shape):
#     102     return self._output_shape(input_shape)
#
# NotImplementedError: Exception encountered when calling Lambda.call().
#
# We could not automatically infer the shape of the Lambda's output. Please specify the `output_shape` argument for this Lambda layer.
#
# Arguments received by Lambda.call():
#   • args=('<KerasTensor shape=(None, 128), dtype=float32, sparse=False, ragged=False, name=keras_tensor_641>',)
#   • kwargs={'mask': 'None'}
